# %% [markdown]
# <a href="https://colab.research.google.com/github/Briasiaj/CSC-302-HW1/blob/main/ICA11_Joshua.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


from google.colab import drive
drive.mount('/content/drive')

df = sns.load_dataset('flights')
df.head()
sns.lineplot(data=df, x='year', y='passengers', hue='month')
plt.xlabel('')
plt.ylabel('Number of Passengers')
plt.title('Monthly Number of Passengers')
plt.savefig('monthly_passengers.png')

sns.relplot(data=df, kind='line')
plt.xlabel('')
plt.ylabel('Number of Passengers')
plt.title('Monthly Number of Passengers')
plt.savefig('monthly_passengers.png')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
