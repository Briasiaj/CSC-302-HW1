# %% [markdown]
# <a href="https://colab.research.google.com/github/Briasiaj/CSC-302-HW1/blob/main/Joshua_ICA4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

file_path = "/content/drive/MyDrive/DATA/lego_setsHB.csv"

df=pd.read_csv(file_path)

print("Dataset Information:")
print(df.info())

print("\nDataset Description:")
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

file_path = "/content/drive/MyDrive/DATA/lego_setsHB.csv"

df=pd.read_csv(file_path)

print("Dataset Information:")
print(df.info())

print("\nDataset Description:")
print(df.describe())

high_rated_logo = df[df['star_rating']>=4]

num_high_rated = high_rated_logo['star_rating'].count()
print(f"\nNumber of lego Sets with star_rating >=4: {num_high_rated}")

df['list_price'] = pd.to_numeric(df['list_price'],errors = 'coerce')
average_price_high_rated = high_rated_logo['list_price'].mean()
print(f"\nAverage price of lego Sets with star_rating >=4: {average_price_high_rated:.2f}")
df['list_price']=df['list_price'].astype(float)
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

file_path = "/content/drive/MyDrive/DATA/lego_setsHB.csv"

df=pd.read_csv(file_path)

print("Dataset Information:")
print(df.info())

print("\nDataset Description:")
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

file_path = "/content/drive/MyDrive/DATA/lego_setsHB.csv"

df=pd.read_csv(file_path)

print("Dataset Information:")
print(df.info())

print("\nDataset Description:")
print(df.describe())

high_rated_logo = df[df['star_rating']>=4]

num_high_rated = high_rated_logo['star_rating'].count()
print(f"\nNumber of lego Sets with star_rating >=4: {num_high_rated}")

df['list_price'] = pd.to_numeric(df['list_price'],errors = 'coerce')
average_price_high_rated = high_rated_logo['list_price'].mean()
print(f"\nAverage price of lego Sets with star_rating >=4: {average_price_high_rated:.2f}")
df['list_price']=df['list_price'].astype(float)
print(f"\nNumber of lego Sets with star_rating >=4: {num_high_rated}")

df['list_price'] = pd.to_numeric(df['list_price'],errors = 'coerce')
average_price_high_rated = high_rated_logo['list_price'].mean()
print(f"\nAverage price of lego Sets with star_rating >=4: {average_price_high_rated:.2f}")
df['list_price']=df['list_price'].astype(float)
# Out:
# Mounted at /content/drive
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   list_price         12261 non-null  float64
#  1   num_reviews        10641 non-null  float64
#  2   piece_count        12261 non-null  int64
#  3   play_star_rating   10486 non-null  float64
#  4   prod_id            12261 non-null  int64
#  5   review_difficulty  10206 non-null  object
#  6   star_rating        10641 non-null  float64
#  7   val_star_rating    10466 non-null  float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 766.4+ KB
# None
#
# Dataset Description:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# ...
